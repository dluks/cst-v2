# %% [markdown]
# # 0.1.8: Species name harmonization (hydraulic traits)
#
# ## Background
#
# When working with ecological datasets from multiple sources, species names often vary due to:
# - Different taxonomic authorities and naming conventions
# - Synonyms and outdated nomenclature
# - Spelling variations and author citations
# - Subspecies, varieties, and cultivars vs. species-level names
#
# The species names from GBIF, sPlot, and TRY all are harmonized against different sources, and so it is important to ensure that they are each harmonized against the same source for direct matching and comparison.

# %% [markdown]
# ## Imports and config

# %%
import dask.dataframe as dd
import numpy as np
import pandas as pd
from src.conf.environment import log

pd.set_option("display.max_columns", None)

# %% [markdown]
# ## TRY growth forms + hydraulic traits harmonization (provided by David Schellenberger Costa)

# %%
dsc_fp = "data/raw/hydraulic_traits_matching_results_2025-10-03.gz"
dsc_df = pd.read_csv(dsc_fp, compression="gzip")

dsc_df.head()
# Out:
# /tmp/ipykernel_643391/3582115669.py:2: DtypeWarning: Columns (0,1,3,4,64) have mixed types. Specify dtype option on import or set low_memory=False.
#   dsc_df = pd.read_csv(dsc_fp, compression="gzip")
#                  hydName              hydNameIn                 nameIn  \
# 0       abarema abbottii       Abarema abbottii       Abarema abbottii
# 1  abarema cochliocarpos  Abarema cochliocarpos  Abarema cochliocarpos
# 2      abarema ganymedea      Abarema ganymedea      Abarema ganymedea
# 3       abarema idiopoda       Abarema idiopoda       Abarema idiopoda
# 4        abarema levelii        Abarema levelii        Abarema levelii
#
#   groName groNameIn  authorsIn               nameIn.1  authorsIn.1 familyLCVP  \
# 0     NaN       NaN        NaN       Abarema abbottii          NaN   Fabaceae
# 1     NaN       NaN        NaN  Abarema cochliocarpos          NaN   Fabaceae
# 2     NaN       NaN        NaN      Abarema ganymedea          NaN   Fabaceae
# 3     NaN       NaN        NaN       Abarema idiopoda          NaN   Fabaceae
# 4     NaN       NaN        NaN        Abarema levelii          NaN   Fabaceae
#
#   statusLCVP             nameInLCVP                          authorsInLCVP  \
# 0    synonym       Abarema abbottii  (Rose & Leonard) Barneby & J.W.Grimes
# 1   accepted  Abarema cochliocarpos           (Gomes) Barneby & J.W.Grimes
# 2    synonym      Abarema ganymedea                   Barneby & J.W.Grimes
# 3    synonym       Abarema idiopoda       (S.F.Blake) Barneby & J.W.Grimes
# 4   accepted        Abarema levelii           (Cowan) Barneby & J.W.Grimes
#
#              nameOutLCVP                             authorsOutLCVP  rowLCVP  \
# 0       Jupunba abbottii            (Rose & Leonard) Britton & Rose    144.0
# 1  Abarema cochliocarpos               (Gomes) Barneby & J.W.Grimes    172.0
# 2      Jupunba ganymedea  (Barneby & J.W.Grimes) M.V.B.Soares & al.    191.0
# 3       Jupunba idiopoda             (S.F.Blake) M.V.B.Soares & al.    199.0
# 4        Abarema levelii               (Cowan) Barneby & J.W.Grimes    216.0
#
#    diffGenLCVP  diffSpecLCVP  diffRestLCVP  diffAuthorsLCVP  matchTypeLCVP  \
# 0          0.0           0.0           0.0              NaN            1.0
# 1          0.0           0.0           0.0              NaN            1.0
# 2          0.0           0.0           0.0              NaN            1.0
# 3          0.0           0.0           0.0              NaN            1.0
# 4          0.0           0.0           0.0              NaN            1.0
#
#    timeLCVP familyWCVP statusWCVP             nameInWCVP  \
# 0       0.0   Fabaceae    synonym       Abarema abbottii
# 1       0.0   Fabaceae   accepted  Abarema cochliacarpos
# 2       0.0   Fabaceae    synonym      Abarema ganymedea
# 3       0.0   Fabaceae    synonym       Abarema idiopoda
# 4       0.0   Fabaceae   accepted        Abarema levelii
#
#                            authorsInWCVP            nameOutWCVP  \
# 0  (Rose & Leonard) Barneby & J.W.Grimes       Jupunba abbottii
# 1           (Gomes) Barneby & J.W.Grimes  Abarema cochliacarpos
# 2                   Barneby & J.W.Grimes      Jupunba ganymedea
# 3       (S.F.Blake) Barneby & J.W.Grimes       Jupunba idiopoda
# 4       (R.S.Cowan) Barneby & J.W.Grimes        Abarema levelii
#
#                                       authorsOutWCVP  rowWCVP  diffGenWCVP  \
# 0                    (Rose & Leonard) Britton & Rose    149.0          0.0
# 1                       (Gomes) Barneby & J.W.Grimes    179.0          0.0
# 2  (Barneby & J.W.Grimes) M.V.B.Soares, M.P.Morim...    197.0          0.0
# 3       (S.F.Blake) M.V.B.Soares, M.P.Morim & Iganci    205.0          0.0
# 4                   (R.S.Cowan) Barneby & J.W.Grimes    221.0          0.0
#
#    diffSpecWCVP  diffRestWCVP  diffAuthorsWCVP  matchTypeWCVP  timeWCVP  \
# 0      0.000000           0.0              NaN            1.0      0.00
# 1      1.666667           0.0              NaN            4.0      6.51
# 2      0.000000           0.0              NaN            1.0      0.00
# 3      0.000000           0.0              NaN            1.0      0.00
# 4      0.000000           0.0              NaN            1.0      0.00
#
#   familyWFO statusWFO              nameInWFO  \
# 0  Fabaceae   synonym       Abarema abbottii
# 1  Fabaceae  accepted  Abarema cochliocarpos
# 2  Fabaceae   synonym      Abarema ganymedea
# 3  Fabaceae   synonym       Abarema idiopoda
# 4  Fabaceae  accepted        Abarema levelii
#
#                             authorsInWFO             nameOutWFO  \
# 0  (Rose & Leonard) Barneby & J.W.Grimes       Jupunba abbottii
# 1           (Gomes) Barneby & J.W.Grimes  Abarema cochliocarpos
# 2                   Barneby & J.W.Grimes      Jupunba ganymedea
# 3       (S.F.Blake) Barneby & J.W.Grimes       Jupunba idiopoda
# 4       (R.S.Cowan) Barneby & J.W.Grimes        Abarema levelii
#
#                                        authorsOutWFO  rowWFO  diffGenWFO  \
# 0                    (Rose & Leonard) Britton & Rose   156.0         0.0
# 1                       (Gomes) Barneby & J.W.Grimes   189.0         0.0
# 2  (Barneby & J.W.Grimes) M.V.B.Soares, M.P.Morim...   208.0         0.0
# 3       (S.F.Blake) M.V.B.Soares, M.P.Morim & Iganci   216.0         0.0
# 4                   (R.S.Cowan) Barneby & J.W.Grimes   233.0         0.0
#
#    diffSpecWFO  diffRestWFO  diffAuthorsWFO  matchTypeWFO  timeWFO  familyWP  \
# 0          0.0          0.0             NaN           1.0      0.0  Fabaceae
# 1          0.0          0.0             NaN           1.0      0.0  Fabaceae
# 2          0.0          0.0             NaN           1.0      0.0  Fabaceae
# 3          0.0          0.0             NaN           1.0      0.0  Fabaceae
# 4          0.0          0.0             NaN           1.0      0.0  Fabaceae
#
#    statusWP               nameInWP                            authorsInWP  \
# 0   synonym       Abarema abbottii  (Rose & Leonard) Barneby & J.W.Grimes
# 1  accepted  Abarema cochliocarpos           (Gomes) Barneby & J.W.Grimes
# 2   synonym      Abarema ganymedea                   Barneby & J.W.Grimes
# 3   synonym       Abarema idiopoda       (S.F.Blake) Barneby & J.W.Grimes
# 4  accepted        Abarema levelii       (R.S.Cowan) Barneby & J.W.Grimes
#
#                nameOutWP                                       authorsOutWP  \
# 0       Jupunba abbottii                    (Rose & Leonard) Britton & Rose
# 1  Abarema cochliocarpos                       (Gomes) Barneby & J.W.Grimes
# 2      Jupunba ganymedea  (Barneby & J.W.Grimes) M.V.B.Soares, M.P.Morim...
# 3       Jupunba idiopoda       (S.F.Blake) M.V.B.Soares, M.P.Morim & Iganci
# 4        Abarema levelii                   (R.S.Cowan) Barneby & J.W.Grimes
#
#    rowWP  diffGenWP  diffSpecWP  diffRestWP  diffAuthorsWP  matchTypeWP  \
# 0  157.0        0.0         0.0         0.0            NaN          1.0
# 1  187.0        0.0         0.0         0.0            NaN          1.0
# 2  205.0        0.0         0.0         0.0            NaN          1.0
# 3  214.0        0.0         0.0         0.0            NaN          1.0
# 4  230.0        0.0         0.0         0.0            NaN          1.0
#
#    timeWP               nameIn.2  authorsIn.2  GBIFKeyGBIF  searchTypeGBIF  \
# 0     0.0       Abarema abbottii          NaN    2977834.0             1.0
# 1     0.0  Abarema cochliocarpos          NaN    2977867.0             1.0
# 2     0.0      Abarema ganymedea          NaN   11456706.0             1.0
# 3     0.0       Abarema idiopoda          NaN   11430363.0             1.0
# 4     0.0        Abarema levelii          NaN    2977916.0             1.0
#
#   synonymGBIF          matchNameGBIF  \
# 0        True       Abarema abbottii
# 1       False  Abarema cochliocarpos
# 2        True      Abarema ganymedea
# 3        True       Abarema idiopoda
# 4       False        Abarema levelii
#
#                            matchedScientificNameGBIF matchedCanonicalNameGBIF  \
# 0  Abarema abbottii (Rose & Leonard) Barneby & J....         Abarema abbottii
# 1  Abarema cochliocarpos (Gomes) Barneby & J.W.Gr...    Abarema cochliocarpos
# 2             Abarema ganymedea Barneby & J.W.Grimes        Abarema ganymedea
# 3  Abarema idiopoda (S.F.Blake) Barneby & J.W.Grimes         Abarema idiopoda
# 4   Abarema levelii (R.S.Cowan) Barneby & J.W.Grimes          Abarema levelii
#
#                    matchedAuthorshipGBIF  diffGenGBIF  diffSpecGBIF  \
# 0  (Rose & Leonard) Barneby & J.W.Grimes          0.0           0.0
# 1           (Gomes) Barneby & J.W.Grimes          0.0           0.0
# 2                   Barneby & J.W.Grimes          0.0           0.0
# 3       (S.F.Blake) Barneby & J.W.Grimes          0.0           0.0
# 4       (R.S.Cowan) Barneby & J.W.Grimes          0.0           0.0
#
#    diffRestGBIF  diffAuthorsGBIF  timeGBIF  \
# 0           0.0              NaN      0.33
# 1           0.0              NaN      0.37
# 2           0.0              NaN      0.36
# 3           0.0              NaN      0.37
# 4           0.0              NaN      0.37
#
#                                   scientificNameGBIF      canonicalNameGBIF  \
# 0   Jupunba abbottii (Rose & Leonard) Britton & Rose       Jupunba abbottii
# 1  Abarema cochliocarpos (Gomes) Barneby & J.W.Gr...  Abarema cochliocarpos
# 2  Jupunba ganymedea (Barneby & J.W.Grimes) M.V.B...      Jupunba ganymedea
# 3  Jupunba idiopoda (S.F.Blake) M.V.B.Soares, M.P...       Jupunba idiopoda
# 4   Abarema levelii (R.S.Cowan) Barneby & J.W.Grimes        Abarema levelii
#
#   rankGBIF                                     authorshipGBIF familyGBIF  \
# 0  SPECIES                    (Rose & Leonard) Britton & Rose   Fabaceae
# 1  SPECIES                       (Gomes) Barneby & J.W.Grimes   Fabaceae
# 2  SPECIES  (Barneby & J.W.Grimes) M.V.B.Soares, M.P.Morim...   Fabaceae
# 3  SPECIES       (S.F.Blake) M.V.B.Soares, M.P.Morim & Iganci   Fabaceae
# 4  SPECIES                   (R.S.Cowan) Barneby & J.W.Grimes   Fabaceae
#
#   orderGBIF      classGBIF    phylumGBIF kingdomGBIF
# 0   Fabales  Magnoliopsida  Tracheophyta     Plantae
# 1   Fabales  Magnoliopsida  Tracheophyta     Plantae
# 2   Fabales  Magnoliopsida  Tracheophyta     Plantae
# 3   Fabales  Magnoliopsida  Tracheophyta     Plantae
# 4   Fabales  Magnoliopsida  Tracheophyta     Plantae

# %%
dsc_df.columns
# Out:
# Index(['hydName', 'hydNameIn', 'nameIn', 'groName', 'groNameIn', 'authorsIn',
#        'nameIn.1', 'authorsIn.1', 'familyLCVP', 'statusLCVP', 'nameInLCVP',
#        'authorsInLCVP', 'nameOutLCVP', 'authorsOutLCVP', 'rowLCVP',
#        'diffGenLCVP', 'diffSpecLCVP', 'diffRestLCVP', 'diffAuthorsLCVP',
#        'matchTypeLCVP', 'timeLCVP', 'familyWCVP', 'statusWCVP', 'nameInWCVP',
#        'authorsInWCVP', 'nameOutWCVP', 'authorsOutWCVP', 'rowWCVP',
#        'diffGenWCVP', 'diffSpecWCVP', 'diffRestWCVP', 'diffAuthorsWCVP',
#        'matchTypeWCVP', 'timeWCVP', 'familyWFO', 'statusWFO', 'nameInWFO',
#        'authorsInWFO', 'nameOutWFO', 'authorsOutWFO', 'rowWFO', 'diffGenWFO',
#        'diffSpecWFO', 'diffRestWFO', 'diffAuthorsWFO', 'matchTypeWFO',
#        'timeWFO', 'familyWP', 'statusWP', 'nameInWP', 'authorsInWP',
#        'nameOutWP', 'authorsOutWP', 'rowWP', 'diffGenWP', 'diffSpecWP',
#        'diffRestWP', 'diffAuthorsWP', 'matchTypeWP', 'timeWP', 'nameIn.2',
#        'authorsIn.2', 'GBIFKeyGBIF', 'searchTypeGBIF', 'synonymGBIF',
#        'matchNameGBIF', 'matchedScientificNameGBIF',
#        'matchedCanonicalNameGBIF', 'matchedAuthorshipGBIF', 'diffGenGBIF',
#        'diffSpecGBIF', 'diffRestGBIF', 'diffAuthorsGBIF', 'timeGBIF',
#        'scientificNameGBIF', 'canonicalNameGBIF', 'rankGBIF', 'authorshipGBIF',
#        'familyGBIF', 'orderGBIF', 'classGBIF', 'phylumGBIF', 'kingdomGBIF'],
#       dtype='object')

# %%
cols = {
    "hydNameIn": "string[pyarrow]",  # Hydraulic trait name
    "groNameIn": "string[pyarrow]",  # Growth form name
    "nameOutWFO": "string[pyarrow]",  # WFO name
    "GBIFKeyGBIF": pd.Int32Dtype(),  # GBIF key
    "nameOutWCVP": "string[pyarrow]",  # WCVP name
}

dsc_df = pd.read_csv(dsc_fp, compression="gzip", usecols=cols.keys(), dtype=cols)

# %% [markdown]
# ## Harmonize GBIF species

# %%
all_species_map = dsc_df.copy()

gbif_fp = "data/raw/all_tracheophyta_non-cult_2024-04-10/all_tracheophyta_non-cult_2024-04-10.parquet/*"

gbif_cols = {
    "specieskey": pd.Int32Dtype(),
    "taxonrank": "string[pyarrow]",
}

gbif_species = (
    dd.read_parquet(gbif_fp, columns=list(gbif_cols.keys()))
    .astype(gbif_cols)
    .query("taxonrank == 'SPECIES'")
    .drop(columns=["taxonrank"])
    .drop_duplicates(subset=["specieskey"])
    .dropna()
    .compute()
)

gbif_species.head(3)
# Out:
#      specieskey
# 56      5389017
# 93      2855398
# 163     2927245

# %%
gbif_species.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 322333 entries, 56 to 99639
# Data columns (total 1 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   specieskey  322333 non-null  Int32
# dtypes: Int32(1)
# memory usage: 4.0 MB

# %%
gbif_matched = pd.merge(
    all_species_map.dropna(subset=["groNameIn"]),
    gbif_species,
    left_on="GBIFKeyGBIF",
    right_on="specieskey",
    how="inner",
)

print(
    f"Matched {gbif_matched.shape[0]} of {all_species_map.shape[0]} hydraulic species "
    f"({(gbif_matched.shape[0] / all_species_map.shape[0]) * 100:.2f}%)"
)
# Out:
# Matched 192812 of 288698 hydraulic species (66.79%)

# %% [markdown]
# ## Harmonize sPlot species

# %%
splot_fp = "data/interim/splot/extracted/vegetation.parquet"

splot_cols = {"Species": "string[pyarrow]"}

splot_species = (
    pd.read_parquet(splot_fp, columns=list(splot_cols.keys()))
    .astype(splot_cols)
    .drop_duplicates(subset=["Species"])
    .dropna()
)

# %%
print(f"sPlot species: {splot_species.shape[0]}")
splot_matched = pd.merge(
    all_species_map.dropna(subset=["groNameIn"]),
    splot_species,
    left_on="nameOutWCVP",
    right_on="Species",
    how="inner",
)

print(
    f"Matched {splot_matched.shape[0]} of {all_species_map.shape[0]} hydraulic species "
    f"({(splot_matched.shape[0] / all_species_map.shape[0]) * 100:.2f}%)"
)
# Out:
# sPlot species: 116086
# Matched 72996 of 288698 hydraulic species (25.28%)
